# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')
df.head(3)
df = df[:200]

# %%
X = df.iloc[:,0:1].values
y = df.iloc[:,-1].values

# %%
plt.scatter(X,y,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(X_test)

# %%
error = y_predict - y_test
error
# Out:
# array([-0.64320982,  0.35679018, -1.40904377,  1.38526189, -0.76348904,
#         2.15109584, -3.82043245,  4.9454015 , -2.40904377, -1.43751548,
#         5.17956755,  1.05928832,  3.20803925, -0.20334943,  2.17956755,
#         2.41373359,  5.15109584,  1.53401282, -2.08307021, -4.90584757,
#         5.00234491,  2.41373359,  1.56248452,  3.20803925, -3.23182114,
#         1.73970716,  1.67637135,  4.20803925, -1.96918338, -2.46598718,
#         6.15109584, -3.38057207, -3.20334943,  0.38526189,  1.38526189,
#         1.53401282, -1.23182114, -2.82043245,  4.76817886, -6.35210036,
#         0.15109584, -1.61473811,  0.9454015 , -8.52932299, -2.82043245,
#        -1.0545985 , -2.23182114,  2.41373359, -4.17487772, -4.40904377,
#        -1.76348904,  0.20803925, -1.82043245, -0.20334943, -4.20334943,
#         3.76817886,  3.56248452, -0.84890416,  1.20803925,  1.35679018])

# %%
from sklearn.metrics import r2_score

score = r2_score(y_test,y_predict)
score
# Out:
# 0.2520564817842308

# %%
plt.scatter(X_test,y_test,color='red',marker='+')
plt.plot(X_test,y_predict)

# %%
lr.coef_, lr.intercept_
# Out:
# (array([0.20569434]), 63.27137506191183)
