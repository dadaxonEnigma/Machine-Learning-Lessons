# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('credit_data.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## Imbalanced 0 = 284315, 1 = 492 not balanced in our data
# ### 0 ---> Legit Transactions
# ### 1 ---> Fraudulent Transactions

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# separating the legit and fraudulent transactions
legit = df[df['Class']==0]
fraudulent = df[df['Class']==1]

# %%
print(legit.shape)
print(fraudulent.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# Undersampling

# %% [markdown]
# build a sample dataset containing similar distribution of Legit and Fraudulent

# %% [markdown]
# Number of Fraudulent Transactions ---> 492 (radomly)

# %%
legit_sample = legit.sample(n=492)
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 190483  128854.0 -0.025797  0.077502  0.878084  0.924585 -0.018931  1.444712
# 258406  158641.0  1.961897  0.005224 -1.893481  0.207936  1.102956  0.684155
# 276535  167154.0 -0.293779  0.313816  0.165903 -0.669512  1.074869 -0.880553
# 246051  153016.0 -1.374632 -0.210410  0.140755  0.082259  1.992276 -1.347423
# 91714    63595.0  1.178161 -0.060901 -0.308290  0.158543 -0.312313 -1.401071
# ...          ...       ...       ...       ...       ...       ...       ...
# 22527    32291.0 -0.269485  0.480377  1.605832 -1.972252 -0.612862 -1.458223
# 194351  130546.0 -0.946459  1.561015  1.208416  2.060800  1.960664  0.592813
# 186147  126973.0 -0.045248  1.082639 -0.908456 -1.165599  1.529936 -1.217899
# 97926    66442.0 -2.637663 -1.004016  1.102532  0.519366  1.751508 -0.648755
# 75071    55886.0 -0.960932  0.099707  0.714640 -2.241170  0.052447  0.273821
#
# ...

# %% [markdown]
# Concattenate the two DataFrame

# %%
new_dataset = pd.concat([legit_sample, fraudulent],axis=0)
new_dataset.shape
# Out:
# (984, 31)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64
